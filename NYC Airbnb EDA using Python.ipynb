# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':(10,8)})

# %% [markdown]
# <font color = blue>
# We imported the required modules and then we loaded the dataset into our environment using pandas.read_csv
# </font>

# %%
airbnb_df=pd.read_csv('Downloads/AB_NYC_2019.csv')
airbnb_df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# <font color = blue>
# Let us check the shape of the dataframe</font>

# %%
airbnb_df.shape
# Out:
# (48895, 13)

# %% [markdown]
# <font color = blue>
# The Data Frame has 48895 rows and 13 columns.
# </font>

# %%
airbnb_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
airbnb_df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           1.090910                        7.143982
# ...

# %% [markdown]
# <font color = blue>
# We check for the missing values in each column of the dataframe using isnull()
# </font>

# %%
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# <font color = blue>
# For security and data privacy issues, we drop the id, host_name and last_review columns from the dataframe</font>

# %%
airbnb_df.drop(['id','host_name','last_review'], axis=1, inplace=True)
airbnb_df.head(5)
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %% [markdown]
# <font color = blue>
# We replace the missing reviews_per_month column values with 0</font>

# %%
airbnb_df.fillna({'reviews_per_month':0}, inplace=True)

# %% [markdown]
# <font color = blue>
# Once replaced, we revierfiy the count of missing values for the columns</font>

# %%
airbnb_df.isnull().sum()
# Out:
# name                              16
# host_id                            0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %% [markdown]
# <font color = blue>
# Let us find the top 10 hosts who have the highest listing in NYC Airbnb and then we plot the results using bar chart</font>

# %%
top_host_df=airbnb_df.host_id.value_counts().head(10)

# %%
top_host_viz=top_host_df.plot(kind='bar')
top_host_viz.set_title('Top 10 Hosts with Highest Listings in NYC')
top_host_viz.set_ylabel('Count')
top_host_viz.set_xlabel('Host IDs')
# Out:
# Text(0.5, 0, 'Host IDs')

# %% [markdown]
# <font color = blue>
# Now, let's  find the listings for top neighbourhoods in NYC and then we again plot the results using bar chart</font>

# %%
neighbourhood_viz_df= airbnb_df.neighbourhood.value_counts().head(10)

neighbourhood_viz=neighbourhood_viz_df.plot(kind='bar')
neighbourhood_viz.set_title('Top 10 Neighbourhood with Highest Listings in NYC')
neighbourhood_viz.set_ylabel('Count')
neighbourhood_viz.set_xlabel('Neighbourhood')
# Out:
# Text(0.5, 0, 'Neighbourhood')

# %% [markdown]
# <font color = blue>
# Now that we know the top neighbourhoods, we will check the most popular room types in the neighbourhoods. We will use sns.catplot for ease of plotting
# </font>

# %%
neighbourhood_roomtyp_df=airbnb_df.loc[airbnb_df['neighbourhood'].isin(['Williamsburg','Bedford-Stuyvesant','Harlem','Bushwick',
                 'Upper West Side','Hell\'s Kitchen','East Village','Upper East Side','Crown Heights','Midtown'])]

neighbourhood_roomtyp_viz=sns.catplot(x='neighbourhood', hue='neighbourhood_group', col='room_type', 
                                      data=neighbourhood_roomtyp_df,kind='count')

neighbourhood_roomtyp_viz.set_xticklabels(rotation=90)

# %% [markdown]
# <font color = blue>
# We could see that for the neighbourhood groups -  Manhattan and Brooklyn. entire home and private room as more popular as compared to shared rooms.
# </font>

# %% [markdown]
# <font color = blue>
# We now remove the listings with price more than 500$ as we can consider them as outliers in our analysis.
# To make visualization easy, we use the cordinates to plot the listings in a map as below
# </font>

# %%
#creating a sub-dataframe with no extreme values / less than 500
airbnb_less_500_df=airbnb_df[airbnb.price < 500]
lat_long_avail_viz=airbnb_less_500_df.plot(kind='scatter', x='longitude', y='latitude', 
                                           label='availability_365', 
                                           c='price',
                  cmap=plt.get_cmap('jet'), colorbar=True, alpha=0.4, figsize=(10,8))
lat_long_avail_viz.legend()

# %%
_names_=[]
#getting name strings from the column and appending it to the list
for name in airbnb_df.name:
    _names_.append(name)
#setting a function that will split those name strings into separate words   
def split_name(name):
    spl=str(name).split()
    return spl
#initializing empty list where we are going to have words counted
_names_for_count_=[]
#getting name string from our list and using split function, later appending to list above
for x in _names_:
    for word in split_name(x):
        word=word.lower()
        _names_for_count_.append(word)

#we are going to use counter
from collections import Counter
#let's see top 25 used words by host to name their listing
_top_25_w=Counter(_names_for_count_).most_common()
_top_25_w=_top_25_w[0:25]

#now let's put our findings in dataframe for further visualizations
sub_w=pd.DataFrame(_top_25_w)
sub_w.rename(columns={0:'Words', 1:'Count'}, inplace=True)

#we are going to use barplot for this visualization
viz_5=sns.barplot(x='Words', y='Count', data=sub_w)
viz_5.set_title('Counts of the top 25 used words for listing names')
viz_5.set_ylabel('Count of words')
viz_5.set_xlabel('Words')
viz_5.set_xticklabels(viz_5.get_xticklabels(), rotation=80)
# Out:
# [Text(0, 0, 'in'),
#  Text(0, 0, 'room'),
#  Text(0, 0, 'bedroom'),
#  Text(0, 0, 'private'),
#  Text(0, 0, 'apartment'),
#  Text(0, 0, 'cozy'),
#  Text(0, 0, 'the'),
#  Text(0, 0, 'to'),
#  Text(0, 0, 'studio'),
#  Text(0, 0, 'brooklyn'),
#  Text(0, 0, 'apt'),
#  Text(0, 0, 'spacious'),
#  Text(0, 0, '1'),
#  Text(0, 0, 'with'),
#  Text(0, 0, '2'),
#  Text(0, 0, 'of'),
#  Text(0, 0, 'east'),
#  Text(0, 0, 'and'),
#  Text(0, 0, 'manhattan'),
#  Text(0, 0, '&'),
#  Text(0, 0, 'park'),
#  Text(0, 0, 'sunny'),
#  Text(0, 0, 'beautiful'),
#  Text(0, 0, 'near'),
#  Text(0, 0, 'williamsburg')]

# %% [markdown]
# <font color = blue>
#
# From the top 25 used listings' name words - we are able to see that hosts are simply describing their listing in a short form with very specific terms for easier search by a potential traveler. The words are 'room', 'bedroom', 'private', 'apartment', 'studio'.
#
# This shows that there are no catchphrases or 'popular/trending' terms that are used for names; hosts use very simple terms describing the space and the area where the listing is.
#
# </font>

# %% [markdown]
# <font color = blue>
#     Latly, what is the mean price of the listings with highest number of reviews ?
# </font>

# %%
airbnb_df.nlargest(10,'number_of_reviews').price.mean()
# Out:
# 65.4
